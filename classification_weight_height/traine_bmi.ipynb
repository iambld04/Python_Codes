# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_data = pd.read_csv(r"D:\Python\classification_weight_height\Weight_Height_knn.csv")

# %%
df_data
# Out:
#    Weight(x2)kg Height(y2)cm        Class
# 0          51kg        167cm  Underweight
# 1          66kg        177cm       Normal
# 2          75kg        169cm   Overweight
# 3          69kg        176cm       Normal
# 4          50kg        173cm  Underweight
# 5          82kg        170cm   Overweight
# 6          65kg        172cm       Normal
# 7          58kg        180cm  Underweight
# 8          68kg        162cm   Overweight
# 9          63kg        165cm       Normal
# 10         52kg        174cm  Underweight
# 11         58kg        169cm       Normal
# 12         78kg        162cm   Overweight
# 13         65kg        168cm       Normal
# 14         62kg        183cm  Underweight
# 15         72kg        180cm       Normal
# 16         80kg        180cm   Overweight
# 17         60kg        178cm  Underweight
# 18         57kg        173cm       Normal
# 19         73kg        164cm   Overweight
# 20         53kg        170cm  Underweight
# ...

# %%
df_data.duplicated().sum()
# Out:
# 0

# %%
df_data.isnull().sum()
# Out:
# Weight(x2)kg    0
# Height(y2)cm    0
# Class           0
# dtype: int64

# %%
df_data['Height(y2)cm'] = df_data['Height(y2)cm'].apply(lambda x: int(x.replace("cm","")))

# %%
df_data['Weight(x2)kg'] = df_data["Weight(x2)kg"].apply(lambda x: int(x.replace("kg","")))

# %%
df_data
# Out:
#     Weight(x2)kg  Height(y2)cm        Class
# 0             51           167  Underweight
# 1             66           177       Normal
# 2             75           169   Overweight
# 3             69           176       Normal
# 4             50           173  Underweight
# 5             82           170   Overweight
# 6             65           172       Normal
# 7             58           180  Underweight
# 8             68           162   Overweight
# 9             63           165       Normal
# 10            52           174  Underweight
# 11            58           169       Normal
# 12            78           162   Overweight
# 13            65           168       Normal
# 14            62           183  Underweight
# 15            72           180       Normal
# 16            80           180   Overweight
# 17            60           178  Underweight
# 18            57           173       Normal
# 19            73           164   Overweight
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Weight(x2)kg  25 non-null     int64
#  1   Height(y2)cm  25 non-null     int64
#  2   Class         25 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 732.0+ bytes

# %%
#input should be in 2D i.e, in DataFrame

# %%
X = df_data.iloc[0:,[0,1]].values
y =df_data.iloc[0:,2].values

# %%
X
# Out:
# array([[ 51, 167],
#        [ 66, 177],
#        [ 75, 169],
#        [ 69, 176],
#        [ 50, 173],
#        [ 82, 170],
#        [ 65, 172],
#        [ 58, 180],
#        [ 68, 162],
#        [ 63, 165],
#        [ 52, 174],
#        [ 58, 169],
#        [ 78, 162],
#        [ 65, 168],
#        [ 62, 183],
#        [ 72, 180],
#        [ 80, 180],
#        [ 60, 178],
#        [ 57, 173],
#        [ 73, 164],
#        [ 53, 170],
#        [ 74, 182],
#        [ 72, 175],
#        [ 53, 163],
#        [ 55, 180]], dtype=int64)

# %%
y
# Out:
# array(['Underweight', 'Normal', 'Overweight', 'Normal', 'Underweight',
#        'Overweight', 'Normal', 'Underweight', 'Overweight', 'Normal',
#        'Underweight', 'Normal', 'Overweight', 'Normal', 'Underweight',
#        'Normal', 'Overweight', 'Underweight', 'Normal', 'Overweight',
#        'Underweight', 'Normal', 'Overweight', 'Normal', 'Underweight'],
#       dtype=object)

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=5,metric='euclidean')

# %%
model.fit(X,y)
# Out:
# KNeighborsClassifier(metric='euclidean')

# %%
model.predict([[56,180]])
# Out:
# array(['Underweight'], dtype=object)

# %%
y_p = model.predict(X)

# %%
y_p
# Out:
# array(['Underweight', 'Normal', 'Overweight', 'Normal', 'Underweight',
#        'Overweight', 'Normal', 'Underweight', 'Overweight', 'Normal',
#        'Underweight', 'Normal', 'Overweight', 'Normal', 'Underweight',
#        'Normal', 'Overweight', 'Underweight', 'Underweight', 'Overweight',
#        'Underweight', 'Normal', 'Normal', 'Normal', 'Underweight'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_score,recall_score,f1_score

# %%
accuracy_score(y,y_p)
# Out:
# 0.92

# %%
confusion_matrix(y,y_p)
# Out:
# array([[9, 0, 1],
#        [1, 6, 0],
#        [0, 0, 8]], dtype=int64)

# %%
print(classification_report(y,y_p,))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.90      0.90        10
#   Overweight       1.00      0.86      0.92         7
#  Underweight       0.89      1.00      0.94         8
#
#     accuracy                           0.92        25
#    macro avg       0.93      0.92      0.92        25
# weighted avg       0.92      0.92      0.92        25

# %%
import joblib
joblib.dump(model,"final_model")
# Out:
# ['final_model']

# %%
# %%writefile app.py
import streamlit as st
import joblib

final_model = joblib.load(r"D:\Python\classification_weight_height\final_model")
st.title("Health Prediction ")
st.subheader("Please enter your height and weight to know about your health condition")
weight = st.slider("Enter the weight",min_value=40,max_value=130,value=55,step=1)
height = st.slider("Enter the height",min_value=135,max_value=180,value=145,step=1)
if(st.button("PREDICT")):
    op = final_model.predict([[weight,height]])
    st.header(f"The person with {weight} kg weight and {height} cm height is {op[0]}")
# Out:
# Overwriting app.py
