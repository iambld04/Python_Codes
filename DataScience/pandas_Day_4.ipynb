# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\lenovo\Downloads\train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
people_age_above_30 = df[(df['Age']>30)]
people_age_above_30
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(columns=['PassengerId'],inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
fruits_data = pd.read_table(r"C:\Users\lenovo\Downloads\fruit_data_with_colors.txt")
fruits_data = pd.read_csv(r"C:\Users\lenovo\Downloads\fruit_data_with_colors.txt",sep='\t')
fruits_data
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
iris = pd.read_csv(r"C:\Users\lenovo\Downloads\IRIS Test data.txt",sep=';',header=None)
iris
# Out:
#       0     1    2     3    4     5    6     7           8
# 0   5.5  0.33  4.2  0.91  1.4  0.06  0.2  0.04      setosa
# 1   4.9  0.16  3.1  0.45  1.5  0.08  0.2  0.04      setosa
# 2   5.0  0.19  3.2  0.50  1.2  0.03  0.2  0.04      setosa
# 3   5.5  0.33  3.5  0.62  1.3  0.05  0.2  0.04      setosa
# 4   4.9  0.16  3.6  0.66  1.4  0.06  0.1  0.01      setosa
# 5   4.4  0.02  3.0  0.41  1.3  0.05  0.2  0.04      setosa
# 6   5.1  0.22  3.4  0.58  1.5  0.08  0.2  0.04      setosa
# 7   5.0  0.19  3.5  0.62  1.3  0.05  0.3  0.08      setosa
# 8   4.5  0.05  2.3  0.12  1.3  0.05  0.3  0.08      setosa
# 9   4.4  0.02  3.2  0.50  1.3  0.05  0.2  0.04      setosa
# 10  5.0  0.19  3.5  0.62  1.6  0.10  0.6  0.20      setosa
# 11  5.1  0.22  3.8  0.75  1.9  0.15  0.4  0.12      setosa
# 12  4.8  0.13  3.0  0.41  1.4  0.06  0.3  0.08      setosa
# 13  5.1  0.22  3.8  0.75  1.6  0.10  0.2  0.04      setosa
# 14  4.6  0.08  3.2  0.50  1.4  0.06  0.2  0.04      setosa
# ...

# %%
iris.rename(columns={0:'Sepal length',1:'T1',2:'Sepal width',3:'T2',4:'Petal length',5:'T3',6:'petal width',7:'T4',8:'Species'})
# Out:
#     Sepal length    T1  Sepal width    T2  Petal length    T3  petal width  \
# 0            5.5  0.33          4.2  0.91           1.4  0.06          0.2
# 1            4.9  0.16          3.1  0.45           1.5  0.08          0.2
# 2            5.0  0.19          3.2  0.50           1.2  0.03          0.2
# 3            5.5  0.33          3.5  0.62           1.3  0.05          0.2
# 4            4.9  0.16          3.6  0.66           1.4  0.06          0.1
# 5            4.4  0.02          3.0  0.41           1.3  0.05          0.2
# 6            5.1  0.22          3.4  0.58           1.5  0.08          0.2
# 7            5.0  0.19          3.5  0.62           1.3  0.05          0.3
# 8            4.5  0.05          2.3  0.12           1.3  0.05          0.3
# 9            4.4  0.02          3.2  0.50           1.3  0.05          0.2
# 10           5.0  0.19          3.5  0.62           1.6  0.10          0.6
# ...

# %%
parquet_file = pd.read_parquet(r"C:\Users\lenovo\Downloads\sample1 1.parquet")
parquet_file
# Out:
#        column0   column1
# 0        first      last
# 1        Jorge     Frank
# 2       Hunter    Moreno
# 3       Esther    Guzman
# 4       Dennis  Stephens
# ..         ...       ...
# 96       Brett    Miller
# 97    Adelaide    Phelps
# 98         Leo   Walters
# 99      Samuel   Schmidt
# 100  Elizabeth    Gordon
#
# [101 rows x 2 columns]

# %%
parquet_file.columns = parquet_file.iloc[0]
parquet_file = parquet_file[1:]
parquet_file.reset_index(drop=True,inplace=True)

# %%
parquet_file
# Out:
# 0       first      last
# 0       Jorge     Frank
# 1      Hunter    Moreno
# 2      Esther    Guzman
# 3      Dennis  Stephens
# 4      Nettie  Franklin
# ..        ...       ...
# 95      Brett    Miller
# 96   Adelaide    Phelps
# 97        Leo   Walters
# 98     Samuel   Schmidt
# 99  Elizabeth    Gordon
#
# [100 rows x 2 columns]

# %%
d = {
    'id': [6,7,8,9,10],
    'Employee': ['Mr. A','Mr. B','Mr. C','Mr. D','Mr. E'],
}

# %%
a1 = pd.DataFrame(d)

# %%
d = {
    'id': [1,2,3,4,5],
    'Employee': ['Mr. X','Mr. Y','Mr. Z','Mr. F','Mr. G'],
}

# %%
a2=pd.DataFrame(d)

# %%
a3 = pd.concat([a2,a1],ignore_index=True)
a3
# Out:
#    id Employee
# 0   1    Mr. X
# 1   2    Mr. Y
# 2   3    Mr. Z
# 3   4    Mr. F
# 4   5    Mr. G
# 5   6    Mr. A
# 6   7    Mr. B
# 7   8    Mr. C
# 8   9    Mr. D
# 9  10    Mr. E

# %%
d = {
    'id': [1,2,3,4,5],
    'Employee': ['Mr. X','Mr. Y','Mr. Z','Mr. F','Mr. G'],
}

a4 = pd.DataFrame(d)

# %%
d = {
    'id': [7,2,6,4,5],
    'LastName': ['Smith','Brown','David','Stark','Renly'],
}

a5 = pd.DataFrame(d)

# %%
pd.merge(a4,a5,how='inner',left_on='id',right_on='id')
# Out:
#    id Employee LastName
# 0   2    Mr. Y    Brown
# 1   4    Mr. F    Stark
# 2   5    Mr. G    Renly

# %%
pd.merge(a4,a5,how='left',left_on='id',right_on='id')
# Out:
#    id Employee LastName
# 0   1    Mr. X      NaN
# 1   2    Mr. Y    Brown
# 2   3    Mr. Z      NaN
# 3   4    Mr. F    Stark
# 4   5    Mr. G    Renly

# %%
pd.merge(a4,a5,how='right',left_on='id',right_on='id')
# Out:
#    id Employee LastName
# 0   7      NaN    Smith
# 1   2    Mr. Y    Brown
# 2   6      NaN    David
# 3   4    Mr. F    Stark
# 4   5    Mr. G    Renly

# %%
pd.merge(a4,a5,how='outer',left_on='id',right_on='id')
# Out:
#    id Employee LastName
# 0   1    Mr. X      NaN
# 1   2    Mr. Y    Brown
# 2   3    Mr. Z      NaN
# 3   4    Mr. F    Stark
# 4   5    Mr. G    Renly
# 5   6      NaN    David
# 6   7      NaN    Smith

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.shape
# Out:
# (891, 11)

# %%
df.duplicated().sum()      #count the number of duplicate rows in a DataFrame
# Out:
# 0

# %%
df.isnull().sum()              #count the number of NULL values in each column
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
# delete the row containing blank values
# delete the columns containing the blank/NaN values
# replace it with 0 or 1 or any convenient value

# %%
df.drop(columns=['Cabin'],inplace=True)

# %%
df['Age'] = df['Age'].fillna(value=df['Age'].mean())

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch            Ticket     Fare Embarked
# ...

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    2
# dtype: int64

# %%
df['Embarked'] = df['Embarked'].fillna(value=df['Embarked'].mode()[0])

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch            Ticket     Fare Embarked
# ...

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df['Name'].value_counts()          # used to count the number of unique Names and their count
# Out:
# Name
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: count, Length: 891, dtype: int64

# %%
df[df['Name']=='Braund, Mr. Owen Harris']
# Out:
#    Survived  Pclass                     Name   Sex   Age  SibSp  Parch  \
# 0         0       3  Braund, Mr. Owen Harris  male  22.0      1      0
#
#       Ticket  Fare Embarked
# 0  A/5 21171  7.25        S

# %%
df.sample(3,random_state=16,replace=False)   # to select 3 random rows and random_state acts like seed

# replace=False is by default it means a row can be selected only once , rows sampled cannot exceeds rows in DataFrame,ensures that the sampled rows are unique
# replace=True means a roq can be selected multiple times, rows sampled can exceed the rows in datFrame, allows for duplicated samples which does no throw an error
# Out:
#      Survived  Pclass                                           Name     Sex  \
# 506         1       2  Quick, Mrs. Frederick Charles (Jane Richards)  female
# 298         1       1                          Saalfeld, Mr. Adolphe    male
# 338         1       3                          Dahl, Mr. Karl Edwart    male
#
#            Age  SibSp  Parch Ticket   Fare Embarked
# 506  33.000000      0      2  26360  26.00        S
# 298  29.699118      0      0  19988  30.50        S
# 338  45.000000      0      0   7598   8.05        S

# %% [markdown]
# # When we need to select particular columns

# %%
df[['Name','Age']]
# Out:
#                                                   Name        Age
# 0                              Braund, Mr. Owen Harris  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.000000
# 2                               Heikkinen, Miss. Laina  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.000000
# 4                             Allen, Mr. William Henry  35.000000
# ..                                                 ...        ...
# 886                              Montvila, Rev. Juozas  27.000000
# 887                       Graham, Miss. Margaret Edith  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  29.699118
# 889                              Behr, Mr. Karl Howell  26.000000
# 890                                Dooley, Mr. Patrick  32.000000
#
# [891 rows x 2 columns]

# %% [markdown]
# # When we want to range of rows and columns to be displayed

# %%
df.iloc[2:7,3:6]    # iloc is used only for integers
# Out:
#       Sex        Age  SibSp
# 2  female  26.000000      0
# 3  female  35.000000      1
# 4    male  35.000000      0
# 5    male  29.699118      0
# 6    male  54.000000      0

# %%
# we can also specify the row and column numbers instead of slicing
df.iloc[[2,3,4,5,6,7],[0,1,2,3,4]]    #the first list is for row and the second one is for column
# Out:
#    Survived  Pclass                                          Name     Sex  \
# 2         1       3                        Heikkinen, Miss. Laina  female
# 3         1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4         0       3                      Allen, Mr. William Henry    male
# 5         0       3                              Moran, Mr. James    male
# 6         0       1                       McCarthy, Mr. Timothy J    male
# 7         0       3                Palsson, Master. Gosta Leonard    male
#
#          Age
# 2  26.000000
# 3  35.000000
# 4  35.000000
# 5  29.699118
# 6  54.000000
# 7   2.000000

# %% [markdown]
# #When we want to select random not just based on the row and column through index as we cant remember the column index so we can
# use .loc to access through column and row names

# %%
df.loc[[2,3,4,5,6,7],['Name','Age','Sex','Survived']]
# Out:
#                                            Name        Age     Sex  Survived
# 2                        Heikkinen, Miss. Laina  26.000000  female         1
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.000000  female         1
# 4                      Allen, Mr. William Henry  35.000000    male         0
# 5                              Moran, Mr. James  29.699118    male         0
# 6                       McCarthy, Mr. Timothy J  54.000000    male         0
# 7                Palsson, Master. Gosta Leonard   2.000000    male         0

# %%
df.iloc[2]    # returns the Series and the row of the DataFrame the output is Series -- 1 Dimensional
# Out:
# Survived                         1
# Pclass                           3
# Name        Heikkinen, Miss. Laina
# Sex                         female
# Age                           26.0
# SibSp                            0
# Parch                            0
# Ticket            STON/O2. 3101282
# Fare                         7.925
# Embarked                         S
# Name: 2, dtype: object

# %%
# we can access a row using iloc 
df.iloc[[0]]       # returns the DataFrame containing the result of the specified row
# Out:
#    Survived  Pclass                     Name   Sex   Age  SibSp  Parch  \
# 0         0       3  Braund, Mr. Owen Harris  male  22.0      1      0
#
#       Ticket  Fare Embarked
# 0  A/5 21171  7.25        S

# %%
df.iloc[2]['Fare']   #returns the Fair value at the index 2
# Out:
# 7.925

# %%
# to change a particular value we can use .replace but it is not recommended to use 
df.iloc[2].replace(7.925,9)
# Out:
# Survived                         1
# Pclass                           3
# Name        Heikkinen, Miss. Laina
# Sex                         female
# Age                           26.0
# SibSp                            0
# Parch                            0
# Ticket            STON/O2. 3101282
# Fare                             9
# Embarked                         S
# Name: 2, dtype: object

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64
