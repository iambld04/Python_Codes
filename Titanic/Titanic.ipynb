# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_data = pd.read_csv(r"D:\Python\Titanic\titanic.csv")

# %%
df_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
survived = df_data[df_data['Age']>=30]

# %%
survived
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_data.drop(columns=['PassengerId'],inplace=True)

# %%
df_data
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# we have a rename method in pandas to change columns name 
# df_data.rename(columns={})

# %%
# parquet_file.columns = parquet_file.iloc[0]
# parquet_file = parquet_file.iloc[1:]
# parquet_file.reset_index(drop = True,inplace=True)

# %%
d = {
    'id': [6,7,8,9,10],
    'Employee': ['A','B','C','D','E']
}

# %%
a1 = pd.DataFrame(d)

# %%
d = {
    'id': [1,2,3,4,5],
    'Employee': ['V','W','X','Y','Z']
}
a2 = pd.DataFrame(d)

# %%
a3 = pd.concat([a2,a1],ignore_index=True)

# %%
pd.merge(a1,a2,how='outer',left_on='id',right_on='id')
# Out:
#    id Employee_x Employee_y
# 0   1        NaN          V
# 1   2        NaN          W
# 2   3        NaN          X
# 3   4        NaN          Y
# 4   5        NaN          Z
# 5   6          A        NaN
# 6   7          B        NaN
# 7   8          C        NaN
# 8   9          D        NaN
# 9  10          E        NaN

# %%
df_data
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df_data.shape
# Out:
# (891, 11)

# %%
df_data.size
# Out:
# 9801

# %%
df_data.duplicated().sum()
# Out:
# 0

# %%
df_data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df_data.drop(columns=['Cabin'],inplace=True)

# %%
df_data
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Embarked
# ...

# %%
df_data['Age'] = df_data['Age'].fillna(value=df_data['Age'].mean())

# %%
df_data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    2
# dtype: int64

# %%
df_data['Embarked'] = df_data['Embarked'].fillna(value=df_data['Embarked'].mode().values[0])

# %%
df_data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df_data.sample(3,random_state=10)   #random_state acts as seed here
# Out:
#      Survived  Pclass                            Name   Sex   Age  SibSp  \
# 590         0       3            Rintamaki, Mr. Matti  male  35.0      0
# 131         0       3  Coelho, Mr. Domingos Fernandeo  male  20.0      0
# 628         0       3       Bostandyeff, Mr. Guentcho  male  26.0      0
#
#      Parch              Ticket    Fare Embarked
# 590      0   STON/O 2. 3101273  7.1250        S
# 131      0  SOTON/O.Q. 3101307  7.0500        S
# 628      0              349224  7.8958        S

# %%
# to select and compare multiple columns

# %%
df_data[['Age','Sex']]
# Out:
#            Age     Sex
# 0    22.000000    male
# 1    38.000000  female
# 2    26.000000  female
# 3    35.000000  female
# 4    35.000000    male
# ..         ...     ...
# 886  27.000000    male
# 887  19.000000  female
# 888  29.699118  female
# 889  26.000000    male
# 890  32.000000    male
#
# [891 rows x 2 columns]

# %%
df_data.iloc[1:,2:5]
# Out:
#                                                   Name     Sex        Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# 5                                     Moran, Mr. James    male  29.699118
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
# [890 rows x 3 columns]

# %%
df_data.sample()
# Out:
#      Survived  Pclass                        Name   Sex   Age  SibSp  Parch  \
# 713         0       3  Larsson, Mr. August Viktor  male  29.0      0      0
#
#     Ticket    Fare Embarked
# 713   7545  9.4833        S

# %%
df_data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.bar(df_data['Survived'].value_counts().index,df_data['Survived'].value_counts().values,width=0.4)
plt.xticks([0,1])
plt.show()

# %%
df_data['Survived'].value_counts().plot(kind='bar')
plt.show()

# %%
import seaborn as sns

# %%
chart = sns.countplot(x='Survived',data=df_data)
chart.set_xlabel('survived v/s Not survived')
chart.set_ylabel('Count of passengers')
chart.set_title('Survival Chances')
plt.show()

# %%
df_data['Pclass'].value_counts().sort_index()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: count, dtype: int64

# %%
df_data['Pclass'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
chart1 = sns.countplot(x=df_data['Pclass'])
chart1.set_xlabel('Classes')
# Out:
# Text(0.5, 0, 'Classes')

# %%
sns.catplot(x=df_data['Pclass'],kind='count',hue=df_data['Survived'])
